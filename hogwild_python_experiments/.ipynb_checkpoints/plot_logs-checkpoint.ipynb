# %%
import pandas as pd
import json
import os
import matplotlib.pyplot as plt
import numpy as np
# Out:
# /home/karna/anaconda3/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /home/karna/anaconda3/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)

# %%
import seaborn as sns

# %%
os.chdir('logs')

# %%
df = pd.DataFrame(columns=['Run_time','Run_mode','Epochs','Nb_Worker','Batch_Size','Val_loss_time','Val_loss_value', 'Train_loss','Accuracy_test'])

# %%
df.head()
# Out:
# Empty DataFrame
# Columns: [Run_time, Run_mode, Epochs, Nb_Worker, Batch_Size, Val_loss_time, Val_loss_value, Train_loss, Accuracy_test]
# Index: []

# %%
def parse_dict(x):
    times = []
    losses = []
    for element in x['losses_val']:
        for k,v in element.items():
            if k=='time':
                times.append(pd.to_datetime(v)) 
            else:
                losses.append(v) 
    losses = np.array(losses)
    times = np.array(times) 
    
    times = (times - times[0])
    times = [x.total_seconds() for x in times]
    return np.array(times), np.array(losses)

# %%
for file in os.listdir():
    if file.startswith("log"):
        with open(file) as f:
            x = json.load(f)[0]
            #print(x.keys())
            
            times,losses = parse_dict(x)
            dict_x = {'Run_time':pd.to_datetime(x['end_time'])-pd.to_datetime(x['start_time']),
                      'Run_mode':x['running_mode'],
                      'Epochs':int(x['sync_epochs']),
                      'Nb_Worker': int(x['n_workers']),
                      'Batch_Size':int(x['batch']),
                      'Val_loss_time':times,
                      'Val_loss_value':losses,
                      'Train_loss':x['losses_train'],
                      'Accuracy_test':x['accuracy_test']}
            df_x  = pd.DataFrame([dict_x], columns=dict_x.keys())
            df  = pd.concat([df_x, df], axis =0, ignore_index=True)

# %%
df[(df['Nb_Worker']==20) & (df['Batch_Size']==1024)]
# Out:
#           Run_time      Run_mode Epochs Nb_Worker Batch_Size  \
# 34 03:54:47.452080   synchronous   2031        20       1024
# 35 00:47:57.788421  asynchronous      0        20       1024
#
#                                         Val_loss_time  \
# 34  [0.0, 7.805177, 15.576463, 23.577641, 30.34469...
# 35  [0.0, 0.92844, 2.65915, 3.876189, 4.752417, 5....
#
#                                        Val_loss_value  \
# 34  [0.9890196697480886, 0.9771178915323958, 0.966...
# 35  [0.9956013387302659, 0.9899708843355068, 0.984...
#
#                                            Train_loss
# 34  [{'worker_idx': 1, 'loss_train': 1.0, 'time': ...
# 35  [{'worker_idx': 5, 'loss_train': 0.99943804740...

# %%
df.sample(5)
# Out:
#           Run_time      Run_mode Epochs Nb_Worker Batch_Size  \
# 17 00:02:15.241350  asynchronous      0         2         32
# 10 01:41:45.849982   synchronous   3729         5       1024
# 13 00:03:06.402292  asynchronous      0         2         64
# 1  00:03:02.702102  asynchronous      0         5         64
# 58 03:30:07.284836   synchronous   3527        10       1024
#
#                                         Val_loss_time  \
# 17  [0.0, 0.038221, 0.18527, 0.224179, 0.349248, 0...
# 10  [0.0, 1.750344, 3.502527, 5.260542, 6.869079, ...
# 13  [0.0, 0.154157, 0.201565, 0.357581, 0.540549, ...
# 1   [0.0, 0.290417, 0.553121, 0.791094, 1.098617, ...
# 58  [0.0, 4.086177, 8.085852, 11.953697, 15.5032, ...
#
#                                        Val_loss_value  \
# 17  [0.995271577896966, 0.9610780069692092, 0.9475...
# 10  [0.9821575834046943, 0.9609251433060088, 0.940...
# 13  [1.0151014938701162, 1.005994517802182, 1.0256...
# 1   [0.9900193967962964, 0.9956098753420278, 0.990...
# 58  [0.9744106321167785, 0.9482004072216679, 0.920...
#
#                                            Train_loss  Accuracy_test
# 17  [{'worker_idx': 0, 'loss_train': 1.02198100090...       0.930674
# 10  [{'worker_idx': 2, 'loss_train': 1.0, 'time': ...       0.931341
# 13  [{'worker_idx': 1, 'loss_train': 0.99775767326...       0.930377
# 1   [{'worker_idx': 3, 'loss_train': 0.98959726095...       0.925889
# 58  [{'worker_idx': 0, 'loss_train': 1.0, 'time': ...       0.932956

# %%
plt.figure(figsize=(14,8))
    
data = df[(df['Run_mode']=='synchronous') & (df['Batch_Size']==128)]
dict_plot = {'workers':data['Nb_Worker'],'test_acc':data['Accuracy_test']}
pd_plot_1 = pd.DataFrame(dict_plot)
pd_plot_1['Implementation'] = 'Hogwild Python synchronous'

data = df[(df['Run_mode']=='asynchronous') & (df['Batch_Size']==128)]
dict_plot = {'workers':data['Nb_Worker'],'test_acc':data['Accuracy_test']}
pd_plot_2 = pd.DataFrame(dict_plot)
pd_plot_2['Implementation'] = 'Hogwild Python asynchronous'

plot_data = pd.concat([pd_plot_1,pd_plot_2],axis=0)


sns.scatterplot(data=plot_data,x='workers',y='test_acc',hue='Implementation')
plt.xticks([1,2,5,10,20])
plt.yticks([0.87,0.88,0.89,0.90,0.91,0.92,0.93,0.94,0.95,0.96])
plt.xlabel('Workers')
plt.ylabel('Test accuracy(%)')
#plt.savefig('plots/time_Vs_worker_101.png',bbox_inches='tight')
# Out:
# Text(0,0.5,'Test accuracy(%)')

# %%
def compute_final_time(df,mode):
    data = df[(df['Run_mode']==mode) & (df['Batch_Size']==128)]
    times = []
    workers = []
    for index, row in data.iterrows():
        losses = row['Val_loss_value']
        min_loss = np.min(losses)
        #print(min_loss)
        for i in range(len(losses)):
            if(losses[i] < min_loss*1.01):
               #print("i",losses[i])
                times.append(row['Val_loss_time'][i])
                workers.append(row['Nb_Worker'])
                break;

    return times,workers

# %%
times,workers = compute_final_time(df,'synchronous')
dict_plot = {'times':times,'workers':workers}
pd_plot_1 = pd.DataFrame(dict_plot)
pd_plot_1['Implementation'] = 'Hogwild Python synchronous'
pd_plot_1.plot(x='workers',y='times',kind='scatter')

# %%
times,workers = compute_final_time(df,'asynchronous')
dict_plot = {'times':times,'workers':workers}
pd_plot_2 = pd.DataFrame(dict_plot)
pd_plot_2['Implementation'] = 'Hogwild Python asynchronous'
pd_plot_2.plot(x='workers',y='times',kind='scatter')

# %%
times_vinc = [9298.58408801,  777.96319582, 2960.40907288, 1961.13169179,2391.25033243]
workers_vinc = [1,2,5,10,20]
dict_plot = {'times':times_vinc,'workers':workers_vinc}
pd_plot_3 = pd.DataFrame(dict_plot)
pd_plot_3['Implementation'] = 'Spark'

# %%
plot_data = pd.concat([pd_plot_1,pd_plot_2,pd_plot_3],axis=0)

# %%
plt.figure(figsize=(14,8))

sns.scatterplot(data=plot_data,x='workers',y='times',hue='Implementation')
plt.xticks([1,2,5,10,20])
plt.xlabel('Workers')
plt.ylabel('Times(s)')
plt.savefig('plots/time_Vs_worker_101.png',bbox_inches='tight')

# %%
def plot_mode_val_vs_time_worker(df,mode,batch):
    data = df[(df['Run_mode']==mode) & (df['Batch_Size']==batch)]

    different_workers = data['Nb_Worker'].unique()
    different_workers = np.sort(different_workers)

    for i in range(len(different_workers)):
        data_single = data[data['Nb_Worker']==different_workers[i]]
        plt.plot(np.array(data_single['Val_loss_time'])[0],np.array(data_single['Val_loss_value'])[0],label=str(different_workers[i]))
        
    #plt.title(f"Validation loss vs Time for a Batch Size = {batch} for {mode} mode")
    plt.xlabel("Time(s)")
    plt.ylabel("Validation loss")
    #plt.axhline(y=0.375)
    #plt.axhline(y=0.275)
    #plt.axvline(x=700)
    #plt.axvline(x=1750)
    plt.legend(title='Workers')
    plt.savefig("plots/"+str(mode)+"_"+str(batch)+".png", bbox_inches='tight')
    plt.show()

# %%
def plot_mode_batch_vs_time_worker(df,mode):
    data = df[(df['Run_mode']==mode)]
    
    different_workers = data['Nb_Worker'].unique()
    different_workers = np.sort(different_workers)

    for i in range(len(different_workers)):
        data_single = data[data['Nb_Worker']==different_workers[i]]
        plt.plot(data_single['Run_time'],data_single['Batch_Size'],label=str(different_workers[i]))
        
    plt.xlabel("Batch Size")
    plt.ylabel("Total Running time")
    plt.legend(title='Workers')
    plt.show()

# %%
def plot_mode_val_vs_time_batch(df,mode,worker):
    data = df[(df['Run_mode']==mode) & (df['Nb_Worker']==worker)]
    
    different_batch = data['Batch_Size'].unique()
    different_batch = np.sort(different_batch)
    
    for i in range(len(different_batch)):
        data_single = data[data['Batch_Size']==different_batch[i]]
        plt.plot(np.array(data_single['Val_loss_time'])[0],np.array(data_single['Val_loss_value'])[0],label=str(different_batch[i]))
        
    #plt.title(f"Validation loss vs Time with {worker} workers for {mode} mode")
    plt.xlabel("Time(s)")
    plt.ylabel("Validation loss")
    plt.legend(title='Batch Size')
    plt.savefig("plots/"+str(mode)+"_"+str(worker)+".png", bbox_inches='tight')

# %%
plt.figure(figsize=(14,8))
plot_mode_val_vs_time_worker(df,"synchronous",128)

# %%
plt.figure(figsize=(14,8)) 
plot_mode_val_vs_time_worker(df,"synchronous",512)

# %%
plt.figure(figsize=(15,8)) 
plt.subplot(1,2,1)
plot_mode_val_vs_time_batch(df,"asynchronous",1)
plt.subplot(1,2,2)
plot_mode_val_vs_time_batch(df,"synchronous",1)

# %%
plt.figure(figsize=(15,8))
plt.subplot(1,2,1)
plot_mode_val_vs_time_batch(df,"asynchronous",2)
plt.subplot(1,2,2)
plot_mode_val_vs_time_batch(df,"synchronous",2)

# %%
plt.figure(figsize=(15,8)) 
plt.subplot(1,2,1)
plot_mode_val_vs_time_batch(df,"asynchronous",5)
plt.subplot(1,2,2)
plot_mode_val_vs_time_batch(df,"synchronous",5)

# %%
plt.figure(figsize=(15,8)) 
plt.subplot(1,2,1)
plot_mode_val_vs_time_batch(df,"asynchronous",10)
plt.subplot(1,2,2)
plot_mode_val_vs_time_batch(df,"synchronous",10)

# %%
plt.figure(figsize=(15,8)) 
plt.subplot(1,2,1)
plot_mode_val_vs_time_batch(df,"asynchronous",20)
plt.subplot(1,2,2)
plot_mode_val_vs_time_batch(df,"synchronous",20)
